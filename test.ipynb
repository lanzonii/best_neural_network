# %%
from pre_processamento_bases import PreProcessamentoBase
import random
from model import ModelTraining
import pickle as pkl
import plotly.express as px
from sklearn.pipeline import Pipeline
import joblib

bases = PreProcessamentoBase

titanic, titanic_preprocessor = bases.get_base_titanic()
cancer, cancer_preprocessor = bases.get_base_cancer_normalized()
adult, adult_preproocessor = bases.get_base_adult()
# Out:
# c:\Users\guilhermelanzoni-ieg\OneDrive - Instituto J&F\Documents\tech_dados_3_ano\data_science\neural_networks\TRIO\pre_processamento_bases.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_titanic["age"].fillna(titanic_mediana_age, inplace= True)

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from t_student import TStudent
import plotly.express as px
from pre_processamento_bases import PreProcessamentoBase

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import pickle

# %%
with open('titanic_100.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
x_train, x_test, y_train, y_test = train_test_split(titanic[0], titanic[1], test_size = 0.2, random_state = 42)

# %%
model = Sequential()

model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=42)))

model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=42)))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), verbose=0)

loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

accuracy
# Out:
# 0.7921348214149475

# %%
model = Sequential()

model.add(Dense(30, activation='tanh', kernel_initializer=GlorotUniform(seed=42)))

model.add(Dense(26, activation='relu', kernel_initializer=GlorotUniform(seed=42)))

model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=42)))

model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), verbose=0)

loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

accuracy
# Out:
# 0.8314606547355652

# %%
neurons = 1
while neurons <= 60:
    for optimizer in ['adam', 'sgd', 'nadam', 'adamax', 'adagrad', 'rmsprop']:
        for activation in ['sigmoid', 'softplus', 'relu', 'tanh']:
            print(f'{neurons}: optimizer = {optimizer}, activation = {activation}')
            neurons += 1
# Out:
# 1: optimizer = adam, activation = sigmoid
# 2: optimizer = adam, activation = softplus
# 3: optimizer = adam, activation = relu
# 4: optimizer = adam, activation = tanh
# 5: optimizer = sgd, activation = sigmoid
# 6: optimizer = sgd, activation = softplus
# 7: optimizer = sgd, activation = relu
# 8: optimizer = sgd, activation = tanh
# 9: optimizer = nadam, activation = sigmoid
# 10: optimizer = nadam, activation = softplus
# 11: optimizer = nadam, activation = relu
# 12: optimizer = nadam, activation = tanh
# 13: optimizer = adamax, activation = sigmoid
# 14: optimizer = adamax, activation = softplus
# 15: optimizer = adamax, activation = relu
# 16: optimizer = adamax, activation = tanh
# 17: optimizer = adagrad, activation = sigmoid
# 18: optimizer = adagrad, activation = softplus
# 19: optimizer = adagrad, activation = relu
# 20: optimizer = adagrad, activation = tanh
# 21: optimizer = rmsprop, activation = sigmoid
# 22: optimizer = rmsprop, activation = softplus
# ...

# %%
pipeline = {
    'scaler': titanic_preprocessor[0],
    'encoder': titanic_preprocessor[1],
    'model': model, 
    'treino': [x_train, y_train],
    'teste': [x_test, y_test]
}
with open('titanic.pkl', 'wb') as file:
    pkl.dump(pipeline, file)

# %%
pipeline = joblib.load("titanic.pkl")
pipeline
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('encoder',
#                  {'adult_male': LabelEncoder(), 'alone': LabelEncoder(),
#                   'class': LabelEncoder(), 'embark_town': LabelEncoder(),
#                   'embarked': LabelEncoder(), 'sex': LabelEncoder(),
#                   'who': LabelEncoder()}),
#                 ('classifier', <Sequential name=sequential_6, built=True>)])

# %%
pipeline.named_steps
# Out:
# {'scaler': StandardScaler(),
#  'encoder': {'sex': LabelEncoder(),
#   'class': LabelEncoder(),
#   'who': LabelEncoder(),
#   'adult_male': LabelEncoder(),
#   'embark_town': LabelEncoder(),
#   'alone': LabelEncoder(),
#   'embarked': LabelEncoder()},
#  'classifier': <Sequential name=sequential_6, built=True>}

# %%
x_train, x_test, y_train, y_test = train_test_split(cancer[0], cancer[1], test_size = 0.2, random_state = 42)

model = Sequential()

model.add(Dense(30, activation='tanh', kernel_initializer=GlorotUniform(seed=42)))

model.add(Dense(26, activation='relu', kernel_initializer=GlorotUniform(seed=42)))

model.add(Dense(1, activation='sigmoid', kernel_initializer=GlorotUniform(seed=42)))

model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), verbose=0)

loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

accuracy

# %%
with open('titanic.pkl', 'rb') as file:
    pipe = pkl.load(file)
